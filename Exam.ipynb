# %%
for i in range(6):
    print('* ' * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(5, 0, -1):
    print('* ' * i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1, 6):
    print('  ' * (5 - i), end='')
    print('* ' * i)
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
for i in range(1, 6):
    print('  ' * (i - 1), end='')
    print('* ' * (6 - i))
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
for i in range(1, 6):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
for i in range(5, 0, -1):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
for i in range(1, 6):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
for i in range(4, 0, -1):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
for i in range(5, 0, -1):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
for i in range(2, 6):
    print('  ' * (5 - i), end='')
    print('* ' * (2 * i - 1))
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
for i in range(1, 10):
    if i < 6:
        print('* '*i)
    else:
        print('* '*(10-i))
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,10):
    if i<6:
        print('  '*(5-i),end='')
        print('* '*i)
    else:
        print('  '*(i-5),end='')
        print('* '*(10-i))
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
for i in range(1,6):
    print('* '*i,end='')
    print('  '*(10-2*i),end='')
    print('* '*i)
# Out:
# *                 *
# * *             * *
# * * *         * * *
# * * * *     * * * *
# * * * * * * * * * *

# %%
for i in range(5,0,-1):
    print('* '*i,end='')
    print('  '*(10-2*i),end='')
    print('* '*i)
# Out:
# * * * * * * * * * *
# * * * *     * * * *
# * * *         * * *
# * *             * *
# *                 *

# %%
for i in range(1,6):
    print('* '*i,end='')
    print('  '*(10-2*i),end='')
    print('* '*i)
for i in range(4,0,-1):
    print('* '*i,end='')
    print('  '*(10-2*i),end='')
    print('* '*i)
# Out:
# *                 *
# * *             * *
# * * *         * * *
# * * * *     * * * *
# * * * * * * * * * *
# * * * *     * * * *
# * * *         * * *
# * *             * *
# *                 *

# %%
for i in range(0,9):
    if i<5:
        print('* '*(5-i))
    else:
        print('* '*(i-3))
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(0,9):
    if i<5:
        print('  '*i,end='')
        print('* '*(5-i))
    else:
        print('  '*(8-i),end='')
        print('* '*(i-3))
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
for i in range(0,9):
    if i<5:
        print('* '*(5-i),end='')
        print('  '*(2*i),end='')
        print('* '*(5-i))
    else:
        print('* '*(i-3),end='')
        print('  '*(16-2*i),end='')
        print('* '*(i-3))
# Out:
# * * * * * * * * * *
# * * * *     * * * *
# * * *         * * *
# * *             * *
# *                 *
# * *             * *
# * * *         * * *
# * * * *     * * * *
# * * * * * * * * * *
